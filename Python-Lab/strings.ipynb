# %%
def function1(s):
    print("String : ",s)
def function2(s):
    print(len(s))
def function3(s):
    str = s[::-1]
    print(str)
def function4(s):
    str = s[::-1]
    if str==s:
        print("Palindrome")
    else:
        print("Not a palindrome")
def function5(s):
    count=0
    for i in range(len(s)):
        if s[i]!=' ':
            count+=1
    print(count)
def function6(s):
    count=0
    for i in range(len(s)):
        if s[i]=='a' or s[i]=='e' or s[i]=='i' or s[i]=='o' or s[i]=='u' or s[i]=='A' or s[i]=='E' or s[i]=='I' or s[i]=='O' or s[i]=='U':
            count+=1
    print(count)
def function7(s):
    st=str(input("Enter second string : "))
    l=len(st)
    flag=0
    for i in range(len(s)-l):
        if s[i:i+l]==st:
            print("Substring found")
            flag=1
            break
    if flag==0:
        print("Substring not found")
def function8(s):
    c1=0
    c2=0
    for i in range(len(s)):
        if ord(s[i])>=65 and ord(s[i])<=90:
            c1+=1
        elif ord(s[i])>=97 and ord(s[i])<=123:
            c2+=1
    print("Lowercase : ",c2)
    print("Uppercase : ",c1)
def function9(s):
    print(s[-1],end='')
    print(s[1:len(s)-1],end='')
    print(s[0])
def function10(s):
    st=str(input("Enter second string : "))
    count=0
    if len(s)!=len(st):
        print("Not anagram")
        return
    for i in range(len(s)):
        for j in range(len(s)):
            if s[i]==s[j]:
                count+=1
                break
    if count==len(s):
        print("Anagram")
    else:
        print("Not anagram")
def function11(s):
    print("Working on it...")
def main():
    s=str(input("Enter string : "))
    print("Choose a task :\n1. Print string\n2. Length of string\n3. Reverse the string\n4. Check Palindrome or not\n5. Count no. of characters\n6. Count no. of vowels\n7. Check substring\n8. Count uppercase and lowercase\n9. Swap first and last character\n10. Check anagram or not\n11. Permutations of string\n0. EXIT\n")
    choice=1
    while(choice):
        choice = int(input("Enter a choice : "))
        if(choice==1):
            function1(s)
        elif(choice==2):
            function2(s)
        elif(choice==3):
            function3(s)
        elif(choice==4):
            function4(s)
        elif(choice==5):
            function5(s)
        elif(choice==6):
            function6(s)
        elif(choice==7):
            function7(s)
        elif(choice==8):
            function8(s)
        elif(choice==9):
            function9(s)
        elif(choice==10):
            function10(s)
        elif(choice==11):
            function11(s)
    print("Exiting...")
main()
# Out:
# Enter string : Nimesh
# Choose a task :
# 1. Print string
# 2. Length of string
# 3. Reverse the string
# 4. Check Palindrome or not
# 5. Count no. of characters
# 6. Count no. of vowels
# 7. Check substring
# 8. Count uppercase and lowercase
# 9. Swap first and last character
# 10. Check anagram or not
# 11. Permutations of string
# 0. EXIT
#
# Enter a choice : 10
# Enter second string : imeshN
# Anagram
# Enter a choice : 0
# Exiting...
